# %%
import pandas as pd
# Out:
# /var/folders/xn/8zmgmsg57rz62g6lyqm77p440000gn/T/ipykernel_7430/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
billboard = pd.read_csv('billboard.csv')
features = pd.read_csv('features.csv')
df = pd.merge(billboard, features, on='pk', how='left', suffixes=('', '_y'))
df.drop([col for col in df.columns if '_y' in col], axis=1, inplace=True)
df.sample(5)
# Out:
#              date  rank                 song  \
# 12149  2022-01-01    60  Meet Me At Our Spot
# 24829  2019-08-03    58                  ME!
# 20691  2020-05-16    65    Social Distancing
# 12713  2021-11-20    24    Chasing After You
# 9446   2022-07-09    79    WE (Warm Embrace)
#
#                                     artist  \
# 12149     THE ANXIETY: WILLOW & Tyler Cole
# 24829  Taylor Swift Featuring Brendon Urie
# 20691                             Lil Baby
# 12713          Ryan Hurd With Maren Morris
# 9446                           Chris Brown
#
#                                                       pk  danceability  \
# 12149  Meet Me At Our Spot_THE ANXIETY: WILLOW & Tyle...         0.773
# 24829            ME!_Taylor Swift Featuring Brendon Urie         0.545
# 20691                         Social Distancing_Lil Baby         0.849
# 12713      Chasing After You_Ryan Hurd With Maren Morris         0.596
# 9446                       WE (Warm Embrace)_Chris Brown         0.695
#
#        energy  key  loudness  mode  ...  liveness  valence    tempo  \
# 12149   0.470  2.0    -7.930   1.0  ...    0.0851    0.399   94.995
# 24829   0.935  0.0    -6.584   1.0  ...    0.9760    0.552   91.014
# 20691   0.640  5.0    -5.150   1.0  ...    0.3210    0.360  126.005
# 12713   0.679  4.0    -6.395   1.0  ...    0.1160    0.479  131.912
# 9446    0.603  1.0    -6.543   1.0  ...    0.0840    0.900   86.987
#
#                  type                      id  \
# 12149  audio_features  07MDkzWARZaLEdKxo6yArG
# 24829  audio_features  5fOV54t6mMYv3H9CsnvU81
# 20691  audio_features  1RrQK0BIyxZaOooNDVSEaZ
# 12713  audio_features  1ZIKpMTRPqhwAoVXWY3tXI
# 9446   audio_features  0sn26qH64SDVoKo2Gm7lYV
#
#                                         uri  \
# 12149  spotify:track:07MDkzWARZaLEdKxo6yArG
# 24829  spotify:track:5fOV54t6mMYv3H9CsnvU81
# 20691  spotify:track:1RrQK0BIyxZaOooNDVSEaZ
# 12713  spotify:track:1ZIKpMTRPqhwAoVXWY3tXI
# 9446   spotify:track:0sn26qH64SDVoKo2Gm7lYV
#
#                                               track_href  \
# 12149  https://api.spotify.com/v1/tracks/07MDkzWARZaL...
# 24829  https://api.spotify.com/v1/tracks/5fOV54t6mMYv...
# 20691  https://api.spotify.com/v1/tracks/1RrQK0BIyxZa...
# 12713  https://api.spotify.com/v1/tracks/1ZIKpMTRPqhw...
# 9446   https://api.spotify.com/v1/tracks/0sn26qH64SDV...
#
#                                             analysis_url duration_ms  \
# 12149  https://api.spotify.com/v1/audio-analysis/07MD...    162680.0
# 24829  https://api.spotify.com/v1/audio-analysis/5fOV...    213027.0
# 20691  https://api.spotify.com/v1/audio-analysis/1RrQ...    137826.0
# 12713  https://api.spotify.com/v1/audio-analysis/1ZIK...    207974.0
# 9446   https://api.spotify.com/v1/audio-analysis/0sn2...    234947.0
#
#       time_signature
# 12149            4.0
# 24829            4.0
# 20691            4.0
# 12713            4.0
# 9446             4.0
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#                rank  danceability        energy           key      loudness  \
# count  26185.000000  26185.000000  26185.000000  26185.000000  26185.000000
# mean      50.591789      0.665264      0.631003      5.132557     -6.401361
# std       28.847590      0.143520      0.156366      3.562474      2.322500
# min        1.000000      0.074600      0.031600      0.000000    -25.938000
# 25%       26.000000      0.563000      0.535000      2.000000     -7.457000
# 50%       51.000000      0.669000      0.643000      5.000000     -6.024000
# 75%       76.000000      0.778000      0.745000      8.000000     -4.887000
# max      100.000000      0.978000      0.997000     11.000000     -0.517000
#
#                mode   speechiness  acousticness  instrumentalness  \
# count  26185.000000  26185.000000  26185.000000      26185.000000
# mean       0.637273      0.112671      0.223158          0.011367
# std        0.480796      0.111675      0.236172          0.082427
# min        0.000000      0.023500      0.000008          0.000000
# 25%        0.000000      0.037600      0.038300          0.000000
# 50%        1.000000      0.059000      0.134000          0.000000
# 75%        1.000000      0.147000      0.335000          0.000009
# max        1.000000      0.699000      0.991000          0.968000
#
#            liveness       valence         tempo   duration_ms  time_signature
# count  26185.000000  26185.000000  26185.000000  2.618500e+04    26185.000000
# mean       0.173297      0.497393    122.677780  1.954506e+05        3.935918
# std        0.125208      0.220818     29.752226  4.042257e+04        0.340987
# min        0.023200      0.032000     53.376000  3.701300e+04        1.000000
# 25%        0.098200      0.328000     97.953000  1.713330e+05        4.000000
# 50%        0.122000      0.489000    121.964000  1.925400e+05        4.000000
# 75%        0.211000      0.663000    143.875000  2.155070e+05        4.000000
# max        0.976000      0.976000    209.942000  1.037907e+06        5.000000
